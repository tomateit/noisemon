# %% [markdown]
# # Wikipedia

# %% [markdown]
# Operating with articles

# %%
import wikipedia

# %%
wikipedia

# %%
import pywikibot
import requests 
import json

site=pywikibot.Site("wikipedia:en")

# %%
page=pywikibot.Page(site, "https://en.wikipedia.org/wiki/Meta_Platforms")
print(page.pageid)
# Out:
# 0

# %%
pywikibot.Page?
# Out:
# Init signature: pywikibot.Page(source, title: str = '', ns=0) -> None
# Docstring:      Page: A MediaWiki page.
# Init docstring: Instantiate a Page object.
# File:           ~/process/dist/app_noisemon/.venv/lib/python3.10/site-packages/pywikibot/page/_pages.py
# Type:           type
# Subclasses:     Category, FilePage, User

# %%
repo = site.data_repository()  # the Wikibase repository for given site

# %%
item = pywikibot.ItemPage(repo, "Q380")  # a repository item
data = item.get()

# %%
data
# Out:
# {'labels': <class 'pywikibot.page._collections.LanguageDict'>({'fr': 'Meta Platforms', 'en': 'Meta Platforms', 'de': 'Meta Platforms', 'ru': 'Meta Platforms', 'en-ca': 'Meta Platforms', 'en-gb': 'Meta Platforms', 'he': 'מטא', 'it': 'Meta Platforms', 'hu': 'Meta', 'fi': 'Meta', 'nb': 'Meta', 'pt-br': 'Meta, Inc.', 'ca': 'Meta Platforms', 'ta': 'பேஸ்புக், இங்க்.', 'be': 'Meta, Inc.', 'oc': 'Meta Platforms', 'ja': 'メタ・プラットフォームズ', 'nl': 'Meta', 'ko': '메타', 'zh-hk': 'Facebook公司', 'zh-cn': 'Meta', 'ar': 'ميتا بلاتفورمز', 'id': 'Meta', 'th': 'เมตา', 'uk': 'Meta Platforms', 'sco': 'Meta Platforms', 'mk': 'Meta Platforms', 'ne': 'फेसबुक इन्क.', 'lv': 'Meta Platforms', 'ro': 'Meta Platforms', 'tl': 'Meta Platforms', 'cs': 'Meta Platforms', 'sk': 'Meta Platforms', 'sr': 'Фејсбук', 'hi': 'मेटा प्लेटफॉर्म्स', 'tt-cyrl': 'Meta Platforms', 'pt': 'Meta, Inc.', 'zh-tw': '臉書公司', 'vi': 'Meta', 'ny': 'Meta Pulatifomu', 'pl': 'Meta Platforms', 'af': 'Meta', 'ast': 'Meta Platforms', 'bar': 'Meta Platforms
# ...
