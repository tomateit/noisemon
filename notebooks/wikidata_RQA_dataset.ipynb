# %% [markdown]
# # Building dataset for retrieval question answering from Wikidata

# %% [markdown]
# Theoretically, wikidata can provide us a fantastic dataset for QRA. The workflow is the following:
# + For a given set of predicates (I elaborate below) ...
# + That do have string values ...
# + With references such as url
#
# ... we can collect the data in a form
# + Question: can be asked by a predicate, synthetically
# + Answer: predicate value
# + Source text: webpage content
#
# The seach can be performed as simply on a page among all mentions, as well as in broader space of mentions.
#
# ***Correctly (after human accession) retrieved statemens (passages) can further populate reference with a matching quote***
# https://www.wikidata.org/wiki/Property:P1683

# %% [markdown]
# ### Properties
# There's a list of properties with desirable qualities:
# + https://www.wikidata.org/wiki/Wikidata:List_of_properties/Wikidata_property_with_datatype_string_that_is_not_an_external_identifier

# %%
from pprint import pprint
from SPARQLWrapper import SPARQLWrapper, JSON, RDF

# %%
sparql = SPARQLWrapper("http://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

# %%
query = """
SELECT ?company ?companyLabel ?val ?ref 
WHERE
{
  # ?company wdt:P31 wd:Q43229 .
  # ?company p:P571 [ 
    prov:wasDerivedFrom [ pr:P854 ?ref ] ;
    ps:P571 ?val
  ].
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en,ru". }
} LIMIT 20
"""

# %%
sparql.setQuery(query)

results = sparql.query().convert()

# %%
pprint(results["results"]["bindings"])
# Out:
# [{'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q169747'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Dahlbusch Verwaltungs-AG',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.gelsenkirchener-geschichten.de/wiki/Zeche_Dahlbusch'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1873-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160112'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Museo del Prado',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.museodelprado.es/museo/historia-del-museo'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1819-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q183629'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Zeche Graf Schwerin',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'http://www.archive.nrw.de/LAV_NRW/jsp/bestand.jsp?archivNr=4&tektId=209&expandId=1'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1872-04-08T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q135891'},
#   'companyLabel': {'type': 'literal', 'value': 'ZAKA', 'xml:lang': 'en'},
#   'ref': {'type': 'uri', 'value': 'http://www.zaka.org.il/about/background'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1989-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q190593'},
#   'companyLabel': {'type': 'literal', 'value': 'OCLC, Inc.', 'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.bloomberg.com/profile/company/7545500Z:US'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1967-07-05T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q190593'},
#   'companyLabel': {'type': 'literal', 'value': 'OCLC, Inc.', 'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.bloomberg.com/profile/company/7545500Z:US'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1967-07-06T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q173959'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Al-Azhar University',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri', 'value': 'https://www.4icu.org/reviews/1239.htm'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1961-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q234110'},
#   'companyLabel': {'type': 'literal', 'value': 'Europeana', 'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://ec.europa.eu/digital-single-market/en/europeana-platform-europes-digital-cultural-collection-responsible-accessible-sustainable-and'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '2008-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q265128'},
#   'companyLabel': {'type': 'literal', 'value': 'Phase5', 'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.p-5.eu/TheLegacy/about/aboutd.html'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1992-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q255998'},
#   'companyLabel': {'type': 'literal', 'value': 'Tara', 'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://cain.ulster.ac.uk/othelem/organ/torgan.htm'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1966-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q269103'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Archaeological Society of Athens',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.archetai.gr/index.php?p=content&section=1&id=1&lang='},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1837-01-06T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q254283'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Royal Swedish Opera',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://tools.wmflabs.org/heritage/api/api.php?action=search&format=json&srcountry=se-bbr&srlanguage=sv&srid=21300000015421'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1898-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q266710'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Czech Space Office',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri', 'value': 'https://www.czechspace.cz/en/cso-brief'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '2003-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q130871'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Berlin International Film Festival',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'http://www.berlinale.de/en/archiv/jahresarchive/1951/01_jahresblatt_1951/01_Jahresblatt_1951.html'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1951-06-06T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q52847'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'European Economic Community',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'http://urn.nb.no/URN:NBN:no-nb_digibok_2008060900023#3'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1958-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8381'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Visual Effects Society',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'http://articles.latimes.com/2006/feb/17/entertainment/et-awards17'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1997-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q51618'},
#   'companyLabel': {'type': 'literal', 'value': 'Guifi.net', 'xml:lang': 'en'},
#   'ref': {'type': 'uri', 'value': 'http://hackstory.net/index.php/Guifi.net'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '2004-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q63056'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'Find a Grave',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.ancestry.com/corporate/about-ancestry/our-brands'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1995-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q314997'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'CBM International',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri', 'value': 'https://www.cbm.org/about-cbm/our-story/'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1908-01-01T00:00:00Z'}},
#  {'company': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q288406'},
#   'companyLabel': {'type': 'literal',
#                    'value': 'European Organisation of Military Associations',
#                    'xml:lang': 'en'},
#   'ref': {'type': 'uri',
#           'value': 'https://www.hcdn.gob.ar/proyectos/proyectoTP.jsp?exp=1828-D-2015'},
#   'val': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#           'type': 'literal',
#           'value': '1972-01-01T00:00:00Z'}}]
